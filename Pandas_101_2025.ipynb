# %% [markdown]
# <a href="https://colab.research.google.com/github/woranut11/dataviz2025/blob/main/Pandas_101_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# ## Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
import pandas as pd
bfs_outcomes_df = pd.read_csv('/2025-01-bedfordshire-outcomes.csv')
display(bfs_outcomes_df.head())
# Out:
#                                             Crime ID    Month  \
# 0  52929bd151e1826911839f4b57e493df892c8ff3fc0952...  2025-01
# 1  29e1591b3a59ab11db949797202743d4eb2a8e009648e0...  2025-01
# 2  618de6846fec73e8ce3cdfef1e1f83a56371214e56d2ee...  2025-01
# 3  ac32fb4e82430d595494425c42d9c456f1a07b24964d61...  2025-01
# 4  b861fd8847708c11a0e49b6d01ac11fbb91f26bfac78c8...  2025-01
#
#            Reported by         Falls within  Longitude   Latitude  \
# 0  Bedfordshire Police  Bedfordshire Police  -0.271341  52.057223
# 1  Bedfordshire Police  Bedfordshire Police  -0.431611  52.005211
# 2  Bedfordshire Police  Bedfordshire Police  -0.564702  51.877476
# 3  Bedfordshire Police  Bedfordshire Police  -0.322350  52.035383
# 4  Bedfordshire Police  Bedfordshire Police  -0.524683  51.903161
#
#                        Location  LSOA code                  LSOA name  \
# 0  On or near King George Close  E01017414  Central Bedfordshire 010E
# ...

# %% [markdown]
# ## Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_stopandsearch ='/content/drive/MyDrive/python2025/Data/2025-01-bedfordshire-stop-and-search.csv'

# %% [markdown]
# ## load data to memory

# %%
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
stopandsearch_df.tail()
# Out:
#                           Type                       Date  \
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 384                         False                 NaN  51.881800  -0.368669
# 385                         False                 NaN  51.878459  -0.422384
# 386                         False                 NaN  51.878459  -0.422384
#
#      Gender Age range                             Self-defined ethnicity  \
# 382  Female   over 34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %%
ex_list =[[[1,2,3],['a','b','c']],
            [['x','y','z'] ,['ab',1,2]],
            [{'a'}]

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
bfs_outcomes_df['Outcome type']
# Out:
# 0                         Unable to prosecute suspect
# 1                         Unable to prosecute suspect
# 2                         Unable to prosecute suspect
# 3       Investigation complete; no suspect identified
# 4       Investigation complete; no suspect identified
#                             ...
# 4338    Investigation complete; no suspect identified
# 4339    Investigation complete; no suspect identified
# 4340    Investigation complete; no suspect identified
# 4341    Investigation complete; no suspect identified
# 4342                      Unable to prosecute suspect
# Name: Outcome type, Length: 4343, dtype: object

# %% [markdown]
# ## list ซ้อน list

# %%
ex_list =[[[1,2,3],['a','b','c']],
            [['x','y','z'] ,['ab',1,2]],
            [{'a':1,'b':2},{'xx':5,'yy':6}]]

# %%
ex_list[1][1][2]
# Out:
# 2

# %%
stopandsearch_df['Outcome'][200]
# Out:
# 'A no further action disposal'

# %%
stopandsearch_df['Outcome'][384:386]
# Out:
# 384            Community resolution
# 385    A no further action disposal
# Name: Outcome, dtype: object

# %%
stopandsearch_df['Outcome'][99]
# Out:
# 'A no further action disposal'

# %%
stopandsearch_df['creator'][99]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'creator'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-37-3685910004.py in <cell line: 0>()
# ----> 1 stopandsearch_df['creator'][99]
#
# ...

# %% [markdown]
# #### .iloc

# %%
stopandsearch_df.iloc[200,-3]
# Out:
# 'A no further action disposal'

# %%
stopandsearch_df.iloc[200,12]
# Out:
# 'A no further action disposal'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table =stopandsearch_df[['Outcome','Age range','Longitude','Self-defined ethnicity']][:5]
smaller_table
# Out:
#                         Outcome Age range  Longitude  \
# 0                        Arrest     25-34   -0.41311
# 1  A no further action disposal     10-17   -0.29660
# 2  A no further action disposal     10-17   -0.29660
# 3  A no further action disposal     10-17   -0.29660
# 4  A no further action disposal     10-17   -0.29660
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
stopandsearch_df.iloc[1:5,:-10]
# Out:
#             Type                       Date  Part of a policing operation  \
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude
# 1                 NaN  52.132059
# 2                 NaN  52.132059
# 3                 NaN  52.132059
# 4                 NaN  52.132059

# %% [markdown]
# ## Table Query (row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# #### อยากได้ row policing operation

# %%
stopandsearch_df[stopandsearch_df['Part of a policing operation'] == True]
# Out:
#                Type                       Date  Part of a policing operation  \
# 8     Person search  2025-01-01T14:35:00+00:00                          True
# 9     Person search  2025-01-01T15:10:00+00:00                          True
# 10    Person search  2025-01-01T15:10:00+00:00                          True
# 21    Person search  2025-01-03T11:22:00+00:00                          True
# 23   Vehicle search  2025-01-03T13:05:00+00:00                          True
# ..              ...                        ...                           ...
# 372   Person search  2025-01-31T13:13:00+00:00                          True
# 373   Person search  2025-01-31T14:00:00+00:00                          True
# 374   Person search  2025-01-31T14:54:00+00:00                          True
# 379   Person search  2025-01-31T19:04:00+00:00                          True
# 380   Person search  2025-01-31T21:00:00+00:00                          True
#
# ...

# %% [markdown]
# ## ตัวอย่าง Table Qurey ง่ายๆ

# %%
smaller_table
# Out:
#                         Outcome Age range  Longitude  \
# 0                        Arrest     25-34   -0.41311
# 1  A no further action disposal     10-17   -0.29660
# 2  A no further action disposal     10-17   -0.29660
# 3  A no further action disposal     10-17   -0.29660
# 4  A no further action disposal     10-17   -0.29660
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...

# %%
smaller_table[[True,False,True,False,False] ]
# Out:
#                         Outcome Age range  Longitude  \
# 0                        Arrest     25-34   -0.41311
# 2  A no further action disposal     10-17   -0.29660
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 2  White - English/Welsh/Scottish/Northern Irish/...

# %% [markdown]
# # quiz 8 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
#
# แสดงวิธีทำดังนี้
# 1. สร้าง list of logics
# 2. query

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (387-25)*[False]

# %%
stopandsearch_df[list_log1+list_logM+list_log2]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# 8                Person search  2025-01-01T14:35:00+00:00
# 9                Person search  2025-01-01T15:10:00+00:00
# 372              Person search  2025-01-31T13:13:00+00:00
# 373              Person search  2025-01-31T14:00:00+00:00
# 374              Person search  2025-01-31T14:54:00+00:00
# 375              Person search  2025-01-31T15:00:00+00:00
# 376              Person search  2025-01-31T16:20:00+00:00
# ...

# %%
# prompt: create list that has 226 members where the first 10 and the last 15 are True, the rest are False.

list_log1 = 10*[True]
list_log2 = 15*[True]
list_logM = (387-25)*[False]

# %% [markdown]
# ## การชี้ค่าในตารางด้วย df[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %% [markdown]
# # Quiz 8-2
# 1.อยากรู้ว่าในเดือนกุมภาพันธ์ ปี 2025 ผู้ที่ถูกเรียกค้น ที่เป็นคน White-English,... เมือง city of london หรือ เมือง cambridgeshire มีเยอะกว่ากัน และ เยอะกว่ากันเท่าไหร่

# %%
london_df = pd.read_csv('/2025-02-city-of-london-stop-and-search.csv')
display(london_df.head())
cambridgeshire_df = pd.read_csv('/2025-02-cambridgeshire-stop-and-search.csv')
display(cambridgeshire_df.head())
# Out:
#                         Type                       Date  \
# 0              Person search  2025-02-01T04:35:33+00:00
# 1              Person search  2025-02-01T14:24:45+00:00
# 2              Person search  2025-02-01T21:28:25+00:00
# 3              Person search  2025-02-01T21:35:37+00:00
# 4  Person and Vehicle search  2025-02-02T01:02:10+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           NaN                 NaN        NaN        NaN
# 1                           NaN                 NaN  51.514267  -0.079838
# 2                           NaN                 NaN  51.511406  -0.075866
# 3                           NaN                 NaN  51.511965  -0.075453
# 4                           NaN                 NaN  51.509797  -0.083600
#
#   Gender Age range                             Self-defined ethnicity  \
# 0   Male     25-34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
 sum(london_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British')
# Out:
# 15

# %%
sum(cambridgeshire_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British')
# Out:
# 69

# %% [markdown]
# ## HW 4(Group) ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุดและมากที่สุด

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##2025-01

# %%
data_all_01 = '/content/drive/MyDrive/python2025/Data/2025-01'

# %%
csv_01 = [f for f in os.listdir(data_all_01) if f.endswith('.csv')]
select_01 = [file for file in csv_01 if 'stop-and-search' in file]
len(select_01)

 # มี 38 เมือง
# Out:
# 38

# %% [markdown]
# ## 2025-02

# %%
data_all_02 = '/content/drive/MyDrive/python2025/Data/2025-02'

# %%
csv_files_02 = [f for f in os.listdir(data_all_02) if f.endswith('.csv')]

# %%
select_files_02 = [file for file in csv_files_02 if 'stop-and-search' in file]
len(select_files_02)

 # มี 38 เมือง
# Out:
# 38

# %% [markdown]
# ##  2025-03

# %%
data_all_03 = '/content/drive/MyDrive/python2025/Data/2025-03'

# %%
csv_files_03 = [f for f in os.listdir(data_all_03) if f.endswith('.csv')]

# %%
select_files_03 = [file for file in csv_files_03 if 'stop-and-search' in file]
len(select_files_03)

 # มี 37 เมือง
# Out:
# 36

# %% [markdown]
# ## *2025-04*

# %%
data_all_04 ='/content/drive/MyDrive/python2025/Data/2025-04'

# %%
csv_files_04 = [f for f in os.listdir(data_all_04) if f.endswith('.csv')]

# %%
select_files_04 = [file for file in csv_files_04 if 'stop-and-search' in file]
len(select_files_04)

 # มี 37 เมือง
# Out:
# 36

# %% [markdown]
# ## 2025-05

# %%
data_all_05 = '/content/drive/MyDrive/python2025/Data/2025-05'

# %%
csv_files_05 = [f for f in os.listdir(data_all_05) if f.endswith('.csv')]

# %%
select_files_05 = [file for file in csv_files_05 if 'stop-and-search' in file]
len(select_files_05)

 # มี 36 เมือง
# Out:
# 36

# %% [markdown]
# ## ดูว่าเดือนไหนมีเมืองอะไรบ้างและเดือนไหนไม่มีเมืองอะไร

# %%
may_data_path = '/content/drive/MyDrive/python2025/Data/2025-05/2025-05-city-of-london-stop-and-search.csv'

# %%
may_df = pd.read_csv(may_data_path)

# %%
may_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-05-01T15:15:52+00:00                           NaN
# 1  Person search  2025-05-01T18:54:29+00:00                           NaN
# 2  Person search  2025-05-01T20:41:52+00:00                           NaN
# 3  Person search  2025-05-01T20:46:35+00:00                           NaN
# 4  Person search  2025-05-01T21:28:28+00:00                           NaN
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.517461  -0.089808   Male     18-24
# 1                 NaN  51.513882  -0.095924   Male     18-24
# 2                 NaN  51.512024  -0.094460   Male   over 34
# 3                 NaN  51.511794  -0.101906   Male   over 34
# 4                 NaN  51.513079  -0.094070   Male   over 34
#
#                               Self-defined ethnicity  \
# 0                       Asian/Asian British - Indian
# ...

# %% [markdown]
# ## ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
# รายการลิสต์ของไฟล์ที่เลือกสำหรับแต่ละเดือน
all_selected_files = [select_01, select_files_02, select_files_03, select_files_04, select_files_05]
data_all_paths = [data_all_01, data_all_02, data_all_03, data_all_04, data_all_05]

# สร้างลิสต์ว่างเพื่อเก็บ dataframes
df_list = []

# วนลูปผ่านข้อมูลของแต่ละเดือน
for month_files, month_path in zip(all_selected_files, data_all_paths):
    # วนลูปผ่านไฟล์ที่เลือกในแต่ละเดือน
    for file_name in month_files:
        file_path = os.path.join(month_path, file_name)
        # แยกชื่อเมืองออกจากชื่อไฟล์
        city_name = file_name.split('-stop-and-search')[0].split('-', 2)[-1]
        try:
            # อ่านไฟล์ CSV
            df = pd.read_csv(file_path)
            # เพิ่มคอลัมน์ 'City'
            df['City'] = city_name
            # เพิ่ม dataframe ไปยังลิสต์
            df_list.append(df)
        except Exception as e:
            print(f"ข้อผิดพลาดในการอ่านไฟล์ {file_path}: {e}")

# นำ dataframes ทั้งหมดมารวมกันเป็น dataframe เดียว
if df_list:
    all_data_df = pd.concat(df_list, ignore_index=True)

    # กรองข้อมูลเฉพาะบันทึกการหยุดตรวจค้นที่มีเชื้อชาติเป็น 'Asian'
    asian_stop_and_search = all_data_df[all_data_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

    # นับจำนวนเหตุการณ์หยุดตรวจค้นของคน Asian ในแต่ละเมือง
    asian_counts_by_city = asian_stop_and_search['City'].value_counts().reset_index()
    asian_counts_by_city.columns = ['City', 'Asian_Stop_and_Search_Count']

    # ค้นหาเมืองที่มีจำนวนน้อยที่สุดและมากที่สุด
    min_city = asian_counts_by_city.loc[asian_counts_by_city['Asian_Stop_and_Search_Count'].idxmin()]
    max_city = asian_counts_by_city.loc[asian_counts_by_city['Asian_Stop_and_Search_Count'].idxmax()]

    print("📉 เมืองที่มีจำนวนการหยุดตรวจค้นบุคคลเชื้อชาติ Asian **น้อยที่สุด** ตลอด 5 เดือน:")
    print(f"➡️ เมือง: {min_city['City']}, จำนวนครั้ง: {min_city['Asian_Stop_and_Search_Count']} ครั้ง\n")

    print("📈 เมืองที่มีจำนวนการหยุดตรวจค้นบุคคลเชื้อชาติ Asian **มากที่สุด** ตลอด 5 เดือน:")
    print(f"➡️ เมือง: {max_city['City']}, จำนวนครั้ง: {max_city['Asian_Stop_and_Search_Count']} ครั้ง")

else:
    print("ไม่พบข้อมูล dataframe ที่โหลดได้")
# Out:
# 📉 เมืองที่มีจำนวนการหยุดตรวจค้นบุคคลเชื้อชาติ Asian **น้อยที่สุด** ตลอด 5 เดือน:
# ➡️ เมือง: durham, จำนวนครั้ง: 5 ครั้ง
#
# 📈 เมืองที่มีจำนวนการหยุดตรวจค้นบุคคลเชื้อชาติ Asian **มากที่สุด** ตลอด 5 เดือน:
# ➡️ เมือง: west-midlands, จำนวนครั้ง: 2104 ครั้ง

# %%
# ตรวจสอบให้แน่ใจว่าคอลัมน์ 'Date' อยู่ในรูปแบบ datetime
all_data_df['Date'] = pd.to_datetime(all_data_df['Date'], errors='coerce')

# แยกเดือนและปีและแปลงเป็นสตริง
all_data_df['Month_Year'] = all_data_df['Date'].dt.to_period('M').astype(str)


# กรองข้อมูลสำหรับบันทึกการหยุดตรวจค้นที่เชื้อชาติเป็น 'Asian'
asian_stop_and_search = all_data_df[all_data_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# จัดกลุ่มตามเมืองและเดือน/ปี และนับจำนวนเหตุการณ์
asian_monthly_counts = asian_stop_and_search.groupby(['City', 'Month_Year']).size().reset_index(name='Asian_Stop_and_Search_Count')

# Pivot ตารางเพื่อให้เมืองเป็นแถวและเดือนเป็นคอลัมน์
asian_monthly_pivot = asian_monthly_counts.pivot_table(
    index='City',
    columns='Month_Year',
    values='Asian_Stop_and_Search_Count'
).fillna(0).astype(int) # เติมค่าที่หายไปด้วย 0 และแปลงเป็นจำนวนเต็ม

# เพิ่มคอลัมน์ยอดรวม
asian_monthly_pivot['Total'] = asian_monthly_pivot.sum(axis=1)

# กำหนดฟังก์ชันสำหรับไฮไลท์ค่าต่ำสุดและสูงสุดในคอลัมน์ 'Total'
def highlight_min_max_total(s):
    is_min = s == s.min()
    is_max = s == s.max()
    return ['background-color: green' if v_max or v_min else '' for v_min, v_max in zip(is_min, is_max)]


print("จำนวนเหตุการณ์หยุดตรวจค้นคน Asian ในแต่ละเมืองแยกตามเดือนพร้อมยอดรวมและไฮไลท์:")

# ใช้ไฮไลท์กับคอลัมน์ 'Total'
styled_df = asian_monthly_pivot.style.apply(highlight_min_max_total, subset=['Total'])

display(styled_df)
# Out:
# /tmp/ipython-input-3630920935.py:5: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   all_data_df['Month_Year'] = all_data_df['Date'].dt.to_period('M').astype(str)
# จำนวนเหตุการณ์หยุดตรวจค้นคน Asian ในแต่ละเมืองแยกตามเดือนพร้อมยอดรวมและไฮไลท์:
# <style type="text/css">
# #T_7dac9_row11_col5, #T_7dac9_row36_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_7dac9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Month_Year</th>
#       <th id="T_7dac9_level0_col0" class="col_heading level0 col0" >2025-01</th>
#       <th id="T_7dac9_level0_col1" class="col_heading level0 col1" >2025-02</th>
#       <th id="T_7dac9_level0_col2" class="col_heading level0 col2" >2025-03</th>
#       <th id="T_7dac9_level0_col3" class="col_heading level0 col3" >2025-04</th>
#       <th id="T_7dac9_level0_col4" class="col_heading level0 col4" >2025-05</th>
# ...

# %% [markdown]
# ## HW 5 (เดี่ยว) แก้จาก code เดิม ยอดรวมทุกเมือง เดือนไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด##

# %%
import pandas as pd
import os
from google.colab import drive

# Mount Google Drive to access the data
drive.mount('/content/drive')

# Define the base path to the data
base_path = '/content/drive/MyDrive/python2025/Data/' # Update this path if your data is in a different location

# Function to read all relevant CSV files and add city and month columns
def read_all_data(base_path):
    all_dfs = []
    months = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))] # Get only directories (months)

    for month in months:
        month_path = os.path.join(base_path, month)
        files = os.listdir(month_path)
        for file in files:
            if 'stop-and-search' in file and file.endswith('.csv'):
                filepath = os.path.join(month_path, file)
                try:
                    df = pd.read_csv(filepath)
                    city = file.replace('-stop-and-search.csv', '').split('-', 2)[-1]
                    df['Police Force'] = city
                    df['Month'] = month
                    all_dfs.append(df)
                except Exception as e:
                    print(f"Error reading file {filepath}: {e}")

    return all_dfs

# Function to count Asian individuals stopped by city
def count_asian_people_by_city(all_dfs):
    asian_by_city = {}

    for df in all_dfs:
        # Ensure 'Self-defined ethnicity' column exists
        if 'Self-defined ethnicity' in df.columns:
            # Filter for rows where ethnicity contains 'Asian'
            asian_df = df[df['Self-defined ethnicity'].str.contains('Asian', na=False)].copy() # Use .copy() to avoid SettingWithCopyWarning

            if not asian_df.empty:
                # Count by city
                city_counts = asian_df['Police Force'].value_counts()
                for city, count in city_counts.items():
                    if city not in asian_by_city:
                        asian_by_city[city] = 0
                    asian_by_city[city] += count
        else:
            print(f"Warning: 'Self-defined ethnicity' column not found in one of the dataframes. Skipping ethnicity count for this file.")

    return asian_by_city

# Main execution
dataframes = read_all_data(base_path)

if dataframes:
    # Count Asian people by city
    counts_by_city = count_asian_people_by_city(dataframes)

    # Print detailed summary for each city
    print("====== สรุปจำนวนการเรียกค้นคนเชื้อสายเอเชียในแต่ละเมืองตลอด 5 เดือน ======")
    if counts_by_city:
        sorted_cities = sorted(counts_by_city.items(), key=lambda item: item[1], reverse=True)
        for city, count in sorted_cities:
            print(f"- เมือง: {city}, จำนวนครั้ง: {count} ครั้ง")
    else:
        print("ไม่พบข้อมูลการเรียกค้นคนเชื้อสายเอเชียในเมืองใดๆ")

else:
    print("ไม่พบไฟล์ข้อมูลที่สามารถอ่านได้ในพาธที่กำหนด")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ====== สรุปจำนวนการเรียกค้นคนเชื้อสายเอเชียในแต่ละเมืองตลอด 5 เดือน ======
# - เมือง: west-midlands, จำนวนครั้ง: 2104 ครั้ง
# - เมือง: metropolitan, จำนวนครั้ง: 2033 ครั้ง
# - เมือง: lancashire, จำนวนครั้ง: 1301 ครั้ง
# - เมือง: thames-valley, จำนวนครั้ง: 718 ครั้ง
# - เมือง: west-yorkshire, จำนวนครั้ง: 537 ครั้ง
# - เมือง: btp, จำนวนครั้ง: 524 ครั้ง
# - เมือง: south-yorkshire, จำนวนครั้ง: 443 ครั้ง
# - เมือง: merseyside, จำนวนครั้ง: 361 ครั้ง
# - เมือง: bedfordshire, จำนวนครั้ง: 322 ครั้ง
# - เมือง: hampshire, จำนวนครั้ง: 275 ครั้ง
# - เมือง: leicestershire, จำนวนครั้ง: 226 ครั้ง
# - เมือง: northumbria, จำนวนครั้ง: 209 ครั้ง
# - เมือง: staffordshire, จำนวนครั้ง: 205 ครั้ง
# - เมือง: hertfordshire, จำนวนครั้ง: 182 ครั้ง
# - เมือง: essex, จำนวนครั้ง: 170 ครั้ง
# - เมือง: kent, จำนวนครั้ง: 162 ครั้ง
# - เมือง: surrey, จำนวนครั้ง: 152 ครั้ง
# ...

# %%
# Filter data for stop and search records where ethnicity is 'Asian'
asian_stop_and_search_all_months = all_data_df[all_data_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# Group by month and year and count the number of incidents
asian_monthly_total_counts = asian_stop_and_search_all_months.groupby('Month_Year').size().reset_index(name='Asian_Stop_and_Search_Count')

# Display the results
display(asian_monthly_total_counts)
# Out:
#   Month_Year  Asian_Stop_and_Search_Count
# 0    2025-01                         2874
# 1    2025-02                         2244
# 2    2025-03                         2131
# 3    2025-04                         2209
# 4    2025-05                         1733

# %%
# Find month with most and fewest stops
if counts_by_month:
    most_month = max(counts_by_month, key=counts_by_month.get)
    fewest_month = min(counts_by_month, key=counts_by_month.get)

    print("\nเดือนที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:")
    print(f"- {most_month}: {counts_by_month[most_month]} ครั้ง")
    print("\nเดือนที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:")
    print(f"- {fewest_month}: {counts_by_month[fewest_month]} ครั้ง")
else:
    print("ไม่พบข้อมูลการเรียกค้นคนเชื้อสายเอเชียในเดือนใดๆ")

# Print city with most and fewest stops (assuming counts_by_city is available from previous cells)
if counts_by_city:
    print("\n====== สรุปผล ======")
    print("เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:")
    print(f"- {most_city}: {counts_by_city[most_city]} ครั้ง")
    print("\nเมืองที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:")
    print(f"- {fewest_city}: {counts_by_city[fewest_city]} ครั้ง")
else:
    print("ไม่พบข้อมูลการเรียกค้นคนเชื้อสายเอเชียในเมืองใดๆ")
# Out:
# เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:
# - 2025-01: 2874 ครั้ง
#
# เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:
# - 2025-05: 1737 ครั้ง
#
# ====== สรุปผล ======
# เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:
# - west-midlands: 2104 ครั้ง
#
# เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:
# - durham: 5 ครั้ง

# %%
# prompt: ลบ row ที่มีค่าว่างใน column description

folk_df = folk_df.dropna(subset=['description'])

# %%
# prompt: ลบ html tags และ html codes ออกจาก text ใน column description ใช้ beautifulsoup

from bs4 import BeautifulSoup

def remove_html_tags(text):
  soup = BeautifulSoup(text, "html.parser")
  cleaned_text = soup.get_text()
  return cleaned_text

folk_df['description'] = folk_df['description'].apply(remove_html_tags)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0          มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่...  นิทานพื้นบ้าน     ไทย
# 1        ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครอ...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['description'][0]
# Out:
# '\xa0 \xa0 \xa0 \xa0 มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า\n\n\xa0 \xa0 \xa0 \xa0"เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งพูดขึ้นมาว่า\xa0\xa0"นายจะร้องได้ไหม?"\n\n\xa0 \xa0 \xa0 \xa0 อีกคนตอบ "มันจะยากอะไร"\n\n\xa0 \xa0 \xa0 \xa0 เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า\n\n\xa0 \xa0 \xa0 \xa0"หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง\xa0เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า\n\n\xa0 \xa0 \xa0 \xa0 "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"\n\n\xa0 \xa0 \xa0 \xa0 คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า\n\n\xa0 \xa0 \xa0 \xa0 "ช้างนี่เหมือนสูบตีเหล็กนะ"\n\n\xa0 \xa0 \xa0 \xa0\xa0คนที
# ...

# %%
# prompt: ลบ \xa0 และ \n ออกไปด้วย

def remove_special_chars(text):
  cleaned_text = text.replace('\xa0', '')
  cleaned_text = cleaned_text.replace('\n', '')
  return cleaned_text

folk_df['description'] = folk_df['description'].apply(remove_special_chars)

# %%
folk_df['description'][0]
# Out:
# '    มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า   "เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"    ตาบอดคนหนึ่งพูดขึ้นมาว่า"นายจะร้องได้ไหม?"    อีกคนตอบ "มันจะยากอะไร"    เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า   "หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"    ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"    ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้างเจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน    ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า    "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"    คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า    "ช้างนี่เหมือนสูบตีเหล็กนะ"   คนที่สามเข้ามาทางด้านข้างของช้าง ก็จับดูทางด้านข้าง    "โอ้ ช้างนี่เหมือนผนังยุ้งข้าวเลย"     คนที่สี่เข้ามาถึง ก็จับไปโดนหูช้าง    "โอ้ ช้างนี่เหมือนภาชนะสำหรับฝัดข้าวเลย"     พอคนที่ห้าเข้ามาถึง ก็เข้าไปจับโดนมือช้างหรืองวงช้าง ก็พูดว่า    "โอ้ช้างนี่มันเหมือนปลิงเลย ปลิงตั
# ...

# %%
# prompt: description ของ row ไหนยาวที่สุด print name และ ความยาว

longest_description = ''
longest_description_name = ''
for index, row in folk_df.iterrows():
  if len(row['description']) > len(longest_description):
    longest_description = row['description']
    longest_description_name = row['title']

print(f'The longest description belongs to "{longest_description_name}" and its length is {len(longest_description)}')
# Out:
# The longest description belongs to "ท้าวหมาหยุ๋ย" and its length is 7825

# %%
# prompt: description ของ row ไหนสั้นที่สุด print name และ ความยาว

shortest_description = None
shortest_description_name = None
for index, row in folk_df.iterrows():
  if shortest_description is None or len(row['description']) < len(shortest_description):
    shortest_description = row['description']
    shortest_description_name = row['title']

print(f'The shortest description belongs to "{shortest_description_name}" and its length is {len(shortest_description)}')
# Out:
# The shortest description belongs to "จักจั่นไม่มีไส้" and its length is 204

# %% [markdown]
# ## HW 5.2

# %%
# prompt: ลบค่าว่างใน column type

folk_df = folk_df.dropna(subset=['type'])

# %%
# prompt: ชนิดของนิทาน (type) ที่มีจำนวน row มากที่สุดและน้อยที่สุด

type_counts = folk_df['type'].value_counts()

most_common_type = type_counts.index[0]
least_common_type = type_counts.index[-1]

print(f"Most common type: {most_common_type}, count: {type_counts[most_common_type]}")
print(f"Least common type: {least_common_type}, count: {type_counts[least_common_type]}")
# Out:
# Most common type: มุขตลก, count: 46
# Least common type: นิทานเข้าแบบ, count: 1

# %% [markdown]
# ### ทำเอง

# %%
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          40       22           40       40       34         0
# นิทานประจำถิ่น      25       14           25       25       23         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          14        5           14       14       11         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              46       31           46       46       42         0
#
#                  language  rights  license  source.uri
# type
# ...

# %% [markdown]
# ### HW 5.3 มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0      มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ...  นิทานพื้นบ้าน     ไทย
# 1     ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครองเม...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['spatial'].unique()
# Out:
# array(['ไทย', 'ไทย,', nan, 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
set(folk_df['spatial']) # set() แปลงให้ input เป็น set
# Out:
# {'นครศรีธรรมราช ไทย',
#  'พัทลุง ไทย',
#  'พัทลุง, ไทย',
#  'พัทลุง, ไทย,',
#  'ราชบุรี ไทย,',
#  'สงขลา ไทย',
#  'ไทย',
#  'ไทย,'}

# %%
folk_df = folk_df.dropna(subset=['spatial'])

# %%
folk_df.shape[0]
# Out:
# 192

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = folk_df.copy()

# %%
this_data.shape #(12423, 3)
# Out:
# (226, 11)

# %%
print(this_data.shape)
print(this_data.dropna().shape)
# Out:
# (226, 11)
# (0, 11)

# %%
this_data.dropna(inplace=True)

# %%
this_data
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data = folk_df.copy()

# %%
this_data
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = this_data.dropna(inplace=True)

# %% [markdown]
# ## ลบเฉพาะ ค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title','description','type']) # สมมติ เราต้องใช้ ค่าใน column 'name','description','type'

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['type'].mode()
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
folk_df['type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df['type'].isnull().any()    # เอาค่าทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True)
# Out:
# False

# %%
folk_df['type'].isnull().all()    # เอาค่าทุกค่าใน list มา AND กัน
# Out:
# False

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %% [markdown]
# # Quiz 7 นิทานเรื่องไหนที่ ค่า spatial เป็น ค่าว่าง (ไม่ใช้ gemini)

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
folk_df['title'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: title, Length: 226, dtype: bool

# %%
folk_df['title'].duplicated().any()
# Out:
# True

# %%
folk_df[folk_df['title'].duplicated(keep=False)]
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.fillna({'type':folk_df['type'].mode()})
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
this_data = folk_df[['title','type','creator']].dropna()

# %%
this_data.groupby('type').count()
# Out:
#                  title  creator
# type
# ตำนานปรัมปรา         8        8
# นิทานชีวิต          22       22
# นิทานประจำถิ่น      15       15
# นิทานผี              2        2
# นิทานมหัศจรรย์      12       12
# นิทานศาสนา           3        3
# นิทานสัตว์           5        5
# นิทานอธิบายเหตุ     25       25
# มุขตลก              33       33

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, title          ตาบอดคลำช้าง
# type         นิทานประจำถิ่น
# creator    อ่อนตา ประกาเวสา
# Name: 0, dtype: object)
# *************************
# (1, title      ขอคำกระฮอกด่อน
# type         ตำนานปรัมปรา
# creator         พ่อใหญ่นู
# Name: 1, dtype: object)
# *************************
# (2, title      ก่องข้าวน้อยฆ่าแม่
# type               นิทานชีวิต
# creator    หนูเวียง แก้วเวียง
# Name: 2, dtype: object)
# *************************
# (3, title            บักหำน้อย
# type                มุขตลก
# creator    สมหวัง ปานพายัพ
# Name: 3, dtype: object)
# *************************
# (4, title          รื้อบ่อน้ำ
# type               มุขตลก
# creator    บุญศรี เกสเสโร
# Name: 4, dtype: object)
# *************************
# (5, title      กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ
# type                                           มุขตลก
# creator                            พัชราภรณ์ เข็มเพชร
# Name: 5, dtype: object)
# *************************
# (6, title        ตำนานกุดนางใย
# ...

# %% [markdown]
# # Quiz 9
#
# - วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
#
# - มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
#
# - คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด

# %%
# prompt: จาก data this_data วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง

count = 0
stories = []
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    count += 1
    stories.append(row['title'])

print(f"There are {count} stories with 'แม่' or 'พ่อ' in the title.")
print("The stories are:")
for story in stories:
  print(story)
# Out:
# There are 19 stories with 'แม่' or 'พ่อ' in the title.
# The stories are:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ

# %%
# prompt: มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน บอกจำนวนด้วย

import pandas
import pandas as pd
import os
from google.colab import drive
from bs4 import BeautifulSoup

# ... (preceding code)

count_life = 0
count_local = 0
for index, row in this_data.iterrows():
  if ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานชีวิต':
    count_life += 1
  elif ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานประจำถิ่น':
    count_local += 1

if count_life > count_local:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานชีวิต ({count_life} stories) than in นิทานประจำถิ่น ({count_local} stories).")
elif count_local > count_life:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานประจำถิ่น ({count_local} stories) than in นิทานชีวิต ({count_life} stories).")
else:
  print(f"There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น ({count_life} stories each).")
# Out:
# There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น (2 stories each).

# %%
# prompt: คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด (พร้อมทั้งอธิบาย code แต่ละบรรทัดด้วย)

# สร้าง dictionary เพื่อเก็บจำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่องสำหรับแต่ละคนแต่ง
creator_counts = {}
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    creator = row['creator']
    if creator not in creator_counts:
      creator_counts[creator] = 0
    creator_counts[creator] += 1

# หาคนแต่งที่มีจำนวนนิทานมากที่สุด
max_count = 0
most_prolific_creator = None
for creator, count in creator_counts.items():
  if count > max_count:
    max_count = count
    most_prolific_creator = creator

print(f"The creator who wrote the most stories with 'แม่' or 'พ่อ' in the title is {most_prolific_creator} with {max_count} stories.")
# Out:
# The creator who most frequently writes stories with 'แม่' or 'พ่อ' in the title is: หนูเวียง แก้วเวียง
# They have written 2 such stories.

# %%
creator_counts
# Out:
# {'หนูเวียง แก้วเวียง': 2,
#  'สุบิน คำยางจ้อง': 1,
#  'ปรางค์ทิพย์ บุญสีลา': 1,
#  'ชลิตา โพธิสาร': 1,
#  'ไพบูลย์ ระหา': 1,
#  'สุนีย์ คุณโพธิ์': 1,
#  'เสาร์ จันกอ': 2,
#  'จันทร์ โพธิ์ไทสง': 1,
#  'อ่อนตา ประกาเวสา': 2,
#  'สมศรี ถอนภูเขียว': 1,
#  'พรม วรรณศิริ': 1,
#  'สุรพันธ์ บุญชู': 1,
#  'เลิศ ประนัดเด': 1,
#  'อาคม  ปาสานัย': 1,
#  'ลาภ  เพ็ญสวัสดิ์': 1,
#  'นวลจันทร์  จีนเมือง': 1}

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# #Quiz9
# - print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา ใช้ iloc

# ... (preceding code)

for i in range(this_data.shape[0]):
  if 'ปู่' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
# Out:
# เขาปู่เขาย่า

# %% [markdown]
# # Dataset ใหม่ ที่มี ตัวเลข

# %%
movie_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/IMDb Movies India.csv', encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# prompt: ถ้า dropna ข้อมูลเหลือกี่ %

remaining_percentage = (movie_df.dropna().shape[0] / movie_df.shape[0]) * 100
print(f"Remaining data after dropna: {remaining_percentage:.2f}%")
# Out:
# Remaining data after dropna: 36.49%

# %%
movie_df = movie_df.dropna()

# %%
# prompt: ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข

# ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)

# %%
movie_df.head()
# Out:
#                                  Name  Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019  109 min
# 3                             #Yaaram  2019  110 min
# 5                ...Aur Pyaar Ho Gaya  1997  147 min
# 6                           ...Yahaan  2005  142 min
# 8                  ?: A Question Mark  2012   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# ...

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)

# %%
movie_df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# ...

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#               Year     Duration       Rating
# count  5659.000000  5659.000000  5659.000000
# mean   1996.247570   133.439124     5.898533
# std      19.741839    25.319939     1.381165
# min    1931.000000    21.000000     1.100000
# 25%    1983.000000   119.000000     5.000000
# 50%    2002.000000   135.000000     6.100000
# 75%    2013.000000   150.000000     6.900000
# max    2021.000000   321.000000    10.000000

# %%
# prompt: สร้างตารางของ​ Director ที่มี Name เยอะที่สุด เอาแค่ข้อมูลของคนที่เยอะที่สุด

# นับจำนวนหนังที่แต่ละ Director กำกับ
director_counts = movie_df['Director'].value_counts()

# หา Director ที่กำกับหนังเยอะที่สุด
most_prolific_director = director_counts.index[0]
num_movies = director_counts[0]

# สร้างตารางของ Director ที่กำกับหนังเยอะที่สุด
most_prolific_director_df = movie_df[movie_df['Director'] == most_prolific_director]

# แสดงตาราง
print(f"Director with most movies: {most_prolific_director} ({num_movies} movies)")
most_prolific_director_df
# Out:
# Director with most movies: David Dhawan (41 movies)
#                                     Name  Year  Duration  \
# 239                          Aag Ka Gola  1990       180
# 397                            Aandhiyan  1990       145
# 408                              Aankhen  1993       170
# 1008                               Andaz  1994       167
# 1596              Bade Miyan Chote Miyan  1998       140
# 1794                       Banarasi Babu  1997       126
# 2408                          Biwi No. 1  1999       159
# 2478                       Bol Radha Bol  1992       164
# 2754                      Chal Mere Bhai  2000       136
# 2903                     Chashme Baddoor  2013       121
# 3098                  Chor Machaaye Shor  2002       145
# 3230                        Coolie No. 1  1995       143
# 3232                        Coolie No. 1  2020       134
# 3562                     Deewana Mastana  1997       140
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
movie_df[movie_df['Director'] == most_prolific_director]['Rating'].mean()
# Out:
# 5.226829268292683

# %%
movie_df[movie_df['Director'] == most_prolific_director].describe()
# Out:
#               Year    Duration     Rating
# count    41.000000   41.000000  41.000000
# mean   1999.804878  145.170732   5.226829
# std       7.460628   15.006503   1.060430
# min    1989.000000  121.000000   2.900000
# 25%    1995.000000  134.000000   4.600000
# 50%    1998.000000  143.000000   5.100000
# 75%    2002.000000  160.000000   6.100000
# max    2020.000000  180.000000   6.700000

# %% [markdown]
# # HW6
# บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง
#
# (พรีเซ็นคนละ 3 นาที slides)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table

# %%
import pandas as pd

# Load the datasets for all 5 months
try:
    jan_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-01-bedfordshire-stop-and-search.csv')
    feb_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-02-city-of-london-stop-and-search.csv')
    mar_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-03-bedfordshire-stop-and-search.csv')
    apr_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-04-bedfordshire-stop-and-search.csv')
    may_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-05-bedfordshire-stop-and-search.csv')

    # Create a dictionary to store the dataframes
    city_data = {
        "Bedfordshire (Jan)": jan_df,
        "City of London (Feb)": feb_df,
        "Bedfordshire (Mar)": mar_df,
        "Bedfordshire (Apr)": apr_df,
        "Bedfordshire (May)": may_df,
    }

    # Create a dictionary to store the counts of Asian individuals stopped
    asian_counts = {}

    # Iterate over the city data and count the number of Asian individuals stopped
    for city, df in city_data.items():
        asian_counts[city] = df[df['Self-defined ethnicity'] == 'Asian/Asian British - Any other Asian background'].shape[0]

    # Find the city with the most and least stops
    most_stops_city = max(asian_counts, key=asian_counts.get)
    least_stops_city = min(asian_counts, key=asian_counts.get)

    # Print the results
    print("City with the most stops of Asian individuals:")
    print(f"- {most_stops_city}: {asian_counts[most_stops_city]} stops")

    print("\nCity with the least stops of Asian individuals:")
    print(f"- {least_stops_city}: {asian_counts[least_stops_city]} stops")

except FileNotFoundError:
    print("One or more of the data files could not be found. Please check the file paths and try again.")
# Out:
# One or more of the data files could not be found. Please check the file paths and try again.

# %%
import os

if os.path.exists('/content/drive/MyDrive/python2025/Data/'):
    print("The directory exists!")
else:
    print("The directory does not exist. Please create it or provide the correct path.")
# Out:
# The directory does not exist. Please create it or provide the correct path.

# %%
import pandas as pd

# Load the datasets for all 5 months
try:
    jan_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-01-bedfordshire-stop-and-search.csv')
    feb_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-02-city-of-london-stop-and-search.csv')
    mar_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-03-bedfordshire-stop-and-search.csv')
    apr_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-04-bedfordshire-stop-and-search.csv')
    may_df = pd.read_csv('/content/drive/MyDrive/python2025/Data/2025-05-bedfordshire-stop-and-search.csv')

    # Create a dictionary to store the dataframes
    city_data = {
        "Bedfordshire (Jan)": jan_df,
        "City of London (Feb)": feb_df,
        "Bedfordshire (Mar)": mar_df,
        "Bedfordshire (Apr)": apr_df,
        "Bedfordshire (May)": may_df,
    }

    # Create a dictionary to store the counts of Asian individuals stopped
    asian_counts = {}

    # Iterate over the city data and count the number of Asian individuals stopped
    for city, df in city_data.items():
        asian_counts[city] = df[df['Self-defined ethnicity'] == 'Asian/Asian British - Any other Asian background'].shape[0]

    # Find the city with the most and least stops
    most_stops_city = max(asian_counts, key=asian_counts.get)
    least_stops_city = min(asian_counts, key=asian_counts.get)

    # Print the results
    print("City with the most stops of Asian individuals:")
    print(f"- {most_stops_city}: {asian_counts[most_stops_city]} stops")

    print("\nCity with the least stops of Asian individuals:")
    print(f"- {least_stops_city}: {asian_counts[least_stops_city]} stops")

except FileNotFoundError:
    print("One or more of the data files could not be found. Please check the file paths and try again.")
# Out:
# One or more of the data files could not be found. Please check the file paths and try again.

# %%
# Create a dictionary to store the counts of Asian individuals stopped
asian_counts = {}

# %%
import os
import pandas as pd

def find_file(file_name, search_paths):
    for path in search_paths:
        full_path = os.path.join(path, file_name)
        if os.path.exists(full_path):
            print(f"Found file: {full_path}")
            return full_path
    return None

# List of common paths to search in Google Drive
search_paths = [
    '/content/drive/MyDrive/',
    '/content/drive/MyDrive/Colab Notebooks/',
    '/content/drive/MyDrive/Data/',
    '/content/drive/MyDrive/python2025/',
    '/content/drive/MyDrive/python2025/Data/',
    '/content/drive/MyDrive/Dataviz2025/',
    '/content/drive/MyDrive/Dataviz2025/Data/',
]

file_names = [
    '2025-01-bedfordshire-stop-and-search.csv',
    '2025-02-city-of-london-stop-and-search.csv',
    '2025-03-bedfordshire-stop-and-search.csv',
    '2025-04-bedfordshire-stop-and-search.csv',
    '2025-05-bedfordshire-stop-and-search.csv'
]

file_paths = {}
for file_name in file_names:
    path = find_file(file_name, search_paths)
    if path:
        file_paths[file_name] = path
    else:
        print(f"Could not find the file: {file_name}. Please check the file name and location.")

if len(file_paths) == len(file_names):
    try:
        # Create a dictionary to store the dataframes
        city_data = {}
        for file_name, file_path in file_paths.items():
            # Extract a representative name for the city/month from the filename
            city_month_name = ' '.join(file_name.split('-')[2:4]).replace('_', ' ').title()
            city_data[city_month_name] = pd.read_csv(file_path)

        # Create a dictionary to store the counts of Asian individuals stopped
        asian_counts = {}

        # Iterate over the city data and count the number of Asian individuals stopped
        for city, df in city_data.items():
            # Check if the 'Self-defined ethnicity' column exists
            if 'Self-defined ethnicity' in df.columns:
                asian_counts[city] = df[df['Self-defined ethnicity'].str.contains('Asian', na=False)].shape[0]
            else:
                print(f"Warning: 'Self-defined ethnicity' column not found in {city}. Skipping.")
                asian_counts[city] = 0


        if asian_counts:
            # Find the city with the most and least stops
            most_stops_city = max(asian_counts, key=asian_counts.get)
            least_stops_city = min(asian_counts, key=asian_counts.get)

            # Print the results
            print("\n--- Analysis Results ---")
            print("City with the most stops of Asian individuals:")
            print(f"- {most_stops_city}: {asian_counts[most_stops_city]} stops")

            print("\nCity with the least stops of Asian individuals:")
            print(f"- {least_stops_city}: {asian_counts[least_stops_city]} stops")
        else:
            print("\nCould not perform analysis because no valid data was found.")

    except Exception as e:
        print(f"\nAn error occurred during analysis: {e}")
else:
    print("\nCould not proceed with analysis because some data files were not found.")
    print("Please ensure the following files are in your Google Drive and accessible:")
    for file_name in file_names:
        if file_name not in file_paths:
            print(f"- {file_name}")
# Out:
# Found file: /content/drive/MyDrive/python2025/Data/2025-01-bedfordshire-stop-and-search.csv
# Could not find the file: 2025-02-city-of-london-stop-and-search.csv. Please check the file name and location.
# Could not find the file: 2025-03-bedfordshire-stop-and-search.csv. Please check the file name and location.
# Could not find the file: 2025-04-bedfordshire-stop-and-search.csv. Please check the file name and location.
# Could not find the file: 2025-05-bedfordshire-stop-and-search.csv. Please check the file name and location.
#
# Could not proceed with analysis because some data files were not found.
# Please ensure the following files are in your Google Drive and accessible:
# - 2025-02-city-of-london-stop-and-search.csv
# - 2025-03-bedfordshire-stop-and-search.csv
# - 2025-04-bedfordshire-stop-and-search.csv
# - 2025-05-bedfordshire-stop-and-search.csv

# %%
import pandas as pd
import os

# Check if the file_paths dictionary exists and is not empty
if 'file_paths' in locals() and file_paths:
    # Create a dictionary to store the dataframes
    city_data = {}
    for file_name, file_path in file_paths.items():
        # Extract a representative name for the city/month from the filename
        city_month_name = ' '.join(file_name.split('-')[2:4]).replace('_', ' ').title()
        city_data[city_month_name] = pd.read_csv(file_path)

    # Create a dictionary to store the counts of Asian individuals stopped
    asian_counts = {}

    # Iterate over the city data and count the number of Asian individuals stopped
    for city, df in city_data.items():
        # Check if the 'Self-defined ethnicity' column exists
        if 'Self-defined ethnicity' in df.columns:
            asian_counts[city] = df[df['Self-defined ethnicity'].str.contains('Asian', na=False)].shape[0]
        else:
            print(f"Warning: 'Self-defined ethnicity' column not found in {city}. Skipping.")
            asian_counts[city] = 0


    if asian_counts:
        # Find the city with the most and least stops
        most_stops_city = max(asian_counts, key=asian_counts.get)
        least_stops_city = min(asian_counts, key=asian_counts.get)

        # Print the results
        print("\n--- Analysis Results ---")
        print("City with the most stops of Asian individuals:")
        print(f"- {most_stops_city}: {asian_counts[most_stops_city]} stops")

        print("\nCity with the least stops of Asian individuals:")
        print(f"- {least_stops_city}: {asian_counts[least_stops_city]} stops")
    else:
        print("\nCould not perform analysis because no valid data was found.")

else:
    print("The 'file_paths' dictionary is not defined. Please run the file discovery code first.")
# Out:
# --- Analysis Results ---
# City with the most stops of Asian individuals:
# - Bedfordshire Stop: 69 stops
#
# City with the least stops of Asian individuals:
# - Bedfordshire Stop: 69 stops

# %%
import os

folder_path = '/content/drive/MyDrive/Python&datavizz2025/data/2025-01'
if os.path.exists(folder_path):
    print("The folder exists!")
else:
    print("The folder does not exist. Please provide the correct path.")
# Out:
# The folder does not exist. Please provide the correct path.

# %%
import pandas as pd
import os
from google.colab import drive

# Mount Google Drive to access the data
drive.mount('/content/drive')

# Define the base path to the data
base_path = '/content/drive/MyDrive/python2025/Data/' # Update this path if your data is in a different location

# Function to read all relevant CSV files and add city and month columns
def read_all_data(base_path):
    all_dfs = []
    months = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))] # Get only directories (months)

    for month in months:
        month_path = os.path.join(base_path, month)
        files = os.listdir(month_path)
        for file in files:
            if 'stop-and-search' in file and file.endswith('.csv'):
                filepath = os.path.join(month_path, file)
                try:
                    df = pd.read_csv(filepath)
                    city = file.replace('-stop-and-search.csv', '').split('-', 2)[-1]
                    df['Police Force'] = city
                    df['Month'] = month
                    all_dfs.append(df)
                except Exception as e:
                    print(f"Error reading file {filepath}: {e}")

    return all_dfs

# Function to count Asian individuals stopped by city and month
def count_asian_people(all_dfs):
    asian_by_city = {}
    asian_by_month = {}

    for df in all_dfs:
        # Ensure 'Self-defined ethnicity' column exists
        if 'Self-defined ethnicity' in df.columns:
            # Filter for rows where ethnicity contains 'Asian'
            asian_df = df[df['Self-defined ethnicity'].str.contains('Asian', na=False)].copy() # Use .copy() to avoid SettingWithCopyWarning

            if not asian_df.empty:
                # Count by city
                city_counts = asian_df['Police Force'].value_counts()
                for city, count in city_counts.items():
                    if city not in asian_by_city:
                        asian_by_city[city] = 0
                    asian_by_city[city] += count

                # Count by month
                month_counts = asian_df['Month'].value_counts()
                for month, count in month_counts.items():
                    if month not in asian_by_month:
                        asian_by_month[month] = 0
                    asian_by_month[month] += count
        else:
            print(f"Warning: 'Self-defined ethnicity' column not found in one of the dataframes. Skipping ethnicity count for this file.")


    return asian_by_city, asian_by_month

# Main execution
dataframes = read_all_data(base_path)

if dataframes:
    # Count Asian people by city and month
    counts_by_city, counts_by_month = count_asian_people(dataframes)

    # Find city with most and fewest stops
    if counts_by_city:
        most_city = max(counts_by_city, key=counts_by_city.get)
        fewest_city = min(counts_by_city, key=counts_by_city.get)

        print("====== สรุปผล ======")
        print("เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:")
        print(f"- {most_city}: {counts_by_city[most_city]} ครั้ง")
        print("\nเมืองที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:")
        print(f"- {fewest_city}: {counts_by_city[fewest_city]} ครั้ง")
    else:
        print("ไม่พบข้อมูลการเรียกค้นคนเชื้อสายเอเชียในเมืองใดๆ")


    # Find month with most and fewest stops
    if counts_by_month:
        most_month = max(counts_by_month, key=counts_by_month.get)
        fewest_month = min(counts_by_month, key=counts_by_month.get)

        print("\nเดือนที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:")
        print(f"- {most_month}: {counts_by_month[most_month]} ครั้ง")
        print("\nเดือนที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:")
        print(f"- {fewest_month}: {counts_by_month[fewest_month]} ครั้ง")
    else:
        print("ไม่พบข้อมูลการเรียกค้นคนเชื้อสายเอเชียในเดือนใดๆ")

else:
    print("ไม่พบไฟล์ข้อมูลที่สามารถอ่านได้ในพาธที่กำหนด")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ====== สรุปผล ======
# เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:
# - west-midlands: 2104 ครั้ง
#
# เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:
# - durham: 5 ครั้ง
#
# เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด:
# - 2025-01: 2874 ครั้ง
#
# เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด:
# - 2025-05: 1737 ครั้ง
